# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Babita\Downloads\archive (10)\bmw.csv")

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
df.tail()
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 10776         2.0
# 10777         2.0
# 10778         2.0
# 10779         2.0
# 10780         2.0

# %%
df.shape
df.info()
df.describe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB
# <bound method NDFrame.describe of            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# ...

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.hist(df['price'], bins=30)
plt.xlabel("Price")
plt.ylabel("Count")
plt.title("Price Distribution")
plt.show()

# %%
sns.countplot(x='fuelType', data=df)
plt.show()

# %%
# Scatter plot: Mileage vs Price
plt.figure()
plt.scatter(df['mileage'], df['price'])
plt.xlabel("Mileage")
plt.ylabel("Price")
plt.title("Scatter Plot of Mileage vs Price (BMW Cars)")
plt.show()

# %%
# Sample data
data = {
    "Region": ["Germany", "India", "United States", "United Kingdom", "Canada"],
    "Search Interest": [100, 85, 78, 65, 55]
}

df = pd.DataFrame(data)

# Bar chart
plt.figure()
plt.bar(df["Region"], df["Search Interest"])
plt.xlabel("Region")
plt.ylabel("Search Interest")
plt.title("Top Regions Searching the Keyword 'BMW'")
plt.show()

# %%
# Sample rising queries mapped to BMW dataset features
data = {
    "Rising Query": [
        "BMW latest models",
        "BMW car price",
        "BMW automatic cars",
        "BMW mileage cars",
        "BMW fuel type",
        "BMW low mileage used cars",
        "BMW engine capacity",
        "BMW road tax cost",
        "BMW fuel efficient cars",
        "BMW new vs old models"
    ],
    "Related BMW Feature": [
        "model, year",
        "price",
        "transmission",
        "mileage, mpg",
        "fuelType",
        "mileage",
        "engineSize",
        "tax",
        "mpg, fuelType",
        "year, price"
    ]
}

df_queries = pd.DataFrame(data)
df_queries
# Out:
#                 Rising Query Related BMW Feature
# 0          BMW latest models         model, year
# 1              BMW car price               price
# 2         BMW automatic cars        transmission
# 3           BMW mileage cars        mileage, mpg
# 4              BMW fuel type            fuelType
# 5  BMW low mileage used cars             mileage
# 6        BMW engine capacity          engineSize
# 7          BMW road tax cost                 tax
# 8    BMW fuel efficient cars       mpg, fuelType
# 9      BMW new vs old models         year, price
